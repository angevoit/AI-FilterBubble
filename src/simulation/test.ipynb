# %% [markdown]
# ## TODO
# - Read original article
# - Research and compare model options and finetuning options
#     - place to start: https://medium.com/georgian-impact-blog/getting-started-with-generative-ai-4-ways-to-customize-your-models-f6871b44cb6a
#
#
# ### Articles Questions
# - Which articles did they use (does this matter for us?)
# - How many articles are there total
# - Are these tweets or articles or both? We have tweet data but that's not what the model is trained on
#
# ### Training Questions
# - Model to use (related computation and costs)
# - Data format
# - Finetuning method
#     - Opts:
#         - standard finetuning followed by Reinforcement learning from simulated human feedback (RLHF)
#         - Supervised Fine-Tuning (SFT)
#     - these could have diff computational costs when used to make 9 distinct models / these could have diff levels of ease depending on the model
#     - let's start with supervised fine-tuning because it's much easier to implement and then move on to RLHF as a next step maybe https://medium.com/@joonbeomkwon/understanding-ai-training-supervised-fine-tuning-vs-reinforcement-learning-from-human-feedback-55d1b65317e0

# %%
import numpy as np
import pickle
import sim_functions as sim

# %% [markdown]
# # Angela Tests these fcns

# %%
with open("../data/balanced_political_news_40k_v2.pkl", "rb") as handle:
        candidate_news = pickle.load(handle)
sim.get_issue_mapping(candidate_news)
# Out:
# {'health care': {-2: [1741577,
#    6556505,
#    5140948,
#    6610906,
#    6588976,
#    5789636,
#    4673793,
#    4703152,
#    2248213,
#    4576657,
#    5966812,
#    3528270,
#    5555146,
#    1156094,
#    1700791,
#    3572542,
#    5611929,
#    1685879,
#    5111453,
#    5242041,
#    688999,
#    6308600,
#    3652843,
#    5033255,
#    6189826,
#    502737,
#    612056,
#    1446205,
#    5467674,
#    3073117,
#    1069476,
#    475,
#    4932244,
#    5363425,
#    5363170,
#    393554,
#    4767015,
#    4277918,
#    4989498,
#    535186,
#    1708564,
#    1728061,
#    393091,
#    4692152,
#    4712781,
#    472974,
#    5920611,
#    1861633,
#    2357521,
#    6053195,
#    6033123,
#    4042188,
#    2979879,
#    3591682,
#    897135,
#    175138,
#    5026510,
#    2969919,
#    5176102,
#    3156455,
#    6231689,
#    1154605,
#    3950067,
#    6410924,
#    472281,
#    405899,
#    523146,
#    2758774,
#    4085556,
#    4901872,
#    5985542,
# ...

# %%
# find first value of candidate_news
for key in candidate_news:
    print(key)
    print(candidate_news[key])
    break

# find keys in the dict 1741577
for key in candidate_news[3060867]:
    print(key)
print(candidate_news[3060867]['title'])
# Out:
# 1741577
# ...

# %%
# user_file = args.prototype_folder + prototype + ".csv"
user_file = "../data/synthetic_user/country first conserv.csv"
user_vec = sim.read_user_csv(user_file)

issue_mapping = sim.get_issue_mapping(candidate_news)

pos, neg = sim.random_bootstrap_v2(
    user_vec, issue_mapping, candidate_news, 100
)

# %%
# print(pos, neg)
# print title from the candidate news data by the keys in pos
for key in pos:
    print(key)
    print(candidate_news[key]["title"])
# Out:
# 4302843
# US health workers 'did not have proper training' for coronavirus
# 5747001
# Did Donald Trump Libel Barack Obama With His Wire “Tapp” Tweets?
# 1802744
# Trump primary challenger Mark Sanford: I would 'absolutely' build border wall as president
# 4505599
# Gabbard calls Warren a 'fake indigenous woman of color' in tweet
# 992886
# Trump: I don't need a China trade deal before the 2020 election
# 285357
# Hillary Clinton’s Benghazi Debacle: Arming Jihadists in Libya . . . and Syria
# 3060867
# Official: Missile aimed at FBI target in Somalia - CNN.com
# 2632959
# House Democrats see progress on -Mexico-Canada trade deal, passage possible this year
# 4157421
# A Tax Plan That Economists Love (And Politicians Hate)
# 4675885
# ‘Buy American!’ President Trump To Sign Executive Order Ending Reliance On Chinese Medical Supplies
# 1937782
# Swalwell Says It’s An ‘Abuse Of Power’ For The President To Remove An Ambassador ‘For Political Reasons’
# 2682890
# ...

# %%
# article text for key 4302843
candidate_news[4302843]["text"]
# Out:
# "Health workers dealing with evacuated Americans held in coronavirus quarantine in California did not have proper training or protective gear and moved on and off military bases, a whistleblower has claimed.          One Federal employee is even said to have stayed in a nearby hotel before leaving on a commercial flight, according to a report seen by The New York Times.          A complaint was said to have been filed Wednesday with the Office of the Special Counsel. It concerns more than a dozen Department of Health and Human Services workers who worked at two military bases in California dealing with Americans evacuated from China in late January and early February.          The U.S. Centers for Disease Control and Prevention on Wednesday confirmed an infection in California in a person who reportedly did not have relevant travel history or exposure to another known patient. The case emerged near the Travis Air Force Base, where part of the whistleblower report is focused.         
# ...

# %%
# user_interaction(user_vector, candidate_news[pk])
